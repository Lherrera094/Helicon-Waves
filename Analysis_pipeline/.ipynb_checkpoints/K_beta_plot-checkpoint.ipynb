# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
filepath = "../Helicon_Parametric_Analysis/RESULTS/"
filename = "generic"
name = "B=20G;n=2e13"

# %%
data0 = pd.read_csv(f"{filepath}Beta_k_relation.csv")
#data0 = data0[ (data0["k"] < 15) & (data0[" beta "] > 0.35) ]
data0 = data0[ (data0["k"] < 15) & (data0[" beta "] > 2.3) ]
data0.columns
# Out:
# Index(['k', ' beta '], dtype='object')

# %%
# %matplotlib notebook
plt.plot(data0[" beta "], data0["k"],label=f"{name}")
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r"$\beta (cm^{-1})$")
plt.ylabel(r"$k(cm^{-1})$")
plt.grid(True)
plt.legend()
plt.savefig(f"{filepath}Images/k_beta_{name}.jpg", dpi=600)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="892.9666666666667">

# %%
filepath = "../Helicon_Parametric_Analysis/RESULTS/"
filename = "generic"
name = "B=20G;n=2e13"

# %%
data0 = pd.read_csv(f"{filepath}eigenvaluesK.csv")
data0.columns
# Out:
# Index(['k', 'lhs', 'rhs'], dtype='object')

# %%
# %matplotlib notebook
plt.plot(data0['k'],data0["rhs"])
plt.plot(data0['k'],data0["lhs"])
#plt.xlabel(r"$\beta (cm^{-1})$")
plt.xlabel(r"$k(cm^{-1})$")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9833333333333">

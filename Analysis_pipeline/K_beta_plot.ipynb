# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data0 = pd.read_csv("../Helicon_Parametric_Analysis/RESULTS/K_beta.csv")
data0 = data0[data0["k"] < 11]
data0.columns
# Out:
# Index(['k', ' beta '], dtype='object')

# %%
# %matplotlib notebook
plt.plot(data0[" beta "], data0["k"])
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r"$\beta (cm^{-1})$")
plt.ylabel(r"$k(cm^{-1})$")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="892.9666666666667">
